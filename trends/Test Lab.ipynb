# %%
import pandas as pd
from datetime import *

# %%
df = pd.read_csv('cases-by-day.csv')

# %%
df.head()
# Out:
#   date_of_interest  CASE_COUNT  PROBABLE_CASE_COUNT  CASE_COUNT_7DAY_AVG  \
# 0       02/29/2020           1                    0                    0
# 1       03/01/2020           0                    0                    0
# 2       03/02/2020           0                    0                    0
# 3       03/03/2020           1                    0                    0
# 4       03/04/2020           5                    0                    0
#
#    ALL_CASE_COUNT_7DAY_AVG  BX_CASE_COUNT  BX_PROBABLE_CASE_COUNT  \
# 0                        0              0                       0
# 1                        0              0                       0
# 2                        0              0                       0
# 3                        0              0                       0
# 4                        0              0                       0
#
#    BX_CASE_COUNT_7DAY_AVG  BX_ALL_CASE_COUNT_7DAY_AVG  BK_CASE_COUNT  ...  \
# ...

# %%
mn_pop = 1694263
nyc_pop = 8804190
p_mn_nyc = mn_pop/nyc_pop
p_mn_nyc
# Out:
# 0.1924382595105285

# %%
df[['month', 'day', 'year']] = df['date_of_interest'].str.split('/', expand=True)

# %%
df
# Out:
#     date_of_interest  CASE_COUNT  PROBABLE_CASE_COUNT  CASE_COUNT_7DAY_AVG  \
# 0         02/29/2020           1                    0                    0
# 1         03/01/2020           0                    0                    0
# 2         03/02/2020           0                    0                    0
# 3         03/03/2020           1                    0                    0
# 4         03/04/2020           5                    0                    0
# ..               ...         ...                  ...                  ...
# 915       09/01/2022        1606                  448                 1601
# 916       09/02/2022        1430                  382                 1567
# 917       09/03/2022         883                  316                 1537
# 918       09/04/2022         930                  334                 1512
# 919       09/05/2022         918                  319                 1338
#
# ...

# %%
df2 = df[(df['month'] == '01') & (df['year'] == '2021')]

# %%
mn_cases_jan = df2['MN_CASE_COUNT'].sum()

# %%
nyc_cases_jan = df2['CASE_COUNT'].sum()

# %%
prob_pos_mn = mn_cases_jan/mn_pop
prob_pos_mn
# Out:
# 0.011412041696005874

# %%
prob_pos_nyc = nyc_cases_jan/nyc_pop
prob_pos_nyc
# Out:
# 0.015741822927492478

# %%
prob_parta = prob_pos_mn/p_mn_nyc

# %%
prob_parta
# Out:
# 0.059302353518643776

# %% [markdown]
# part b

# %%
prob_partb = prob_pos_mn/prob_pos_nyc

# %%
prob_partb
# Out:
# 0.7249504551391688

# %%
df['date_of_interest'] = df['date_of_interest'].map(lambda x: dt.datetime.strptime(x,'%m/%d/%Y'))

# %%
d = date(1,1,2021)
e = date(1,31,2021)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 d = date(1,1,2021)
#       2 e = date(1,31,2021)
#
# ValueError: day is out of range for month

# %%
df2 = df[(df['date_of_interest'] >=  1/ 1/2021) & (df['date_of_interest'] <= 1/31/2021)]
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py:1008, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1007 try:
# -> 1008     other = self._validate_comparison_value(other)
#    1009 except InvalidComparison:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py:542, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     541 elif not is_list_like(other):
# --> 542     raise InvalidComparison(other)
#     544 elif len(other) != len(self):
#
# InvalidComparison: 0.0004948045522018803
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ...
